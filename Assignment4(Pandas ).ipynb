# %%
# import data from csv
import pandas as pd
df=pd.read_csv('fortune1000.csv')
df
# Out:
#      Rank                            Company                        Sector  \
# 0       1                            Walmart                     Retailing
# 1       2                        Exxon Mobil                        Energy
# 2       3                              Apple                    Technology
# 3       4                 Berkshire Hathaway                    Financials
# 4       5                           McKesson                   Health Care
# 5       6                 UnitedHealth Group                   Health Care
# 6       7                         CVS Health          Food and Drug Stores
# 7       8                     General Motors        Motor Vehicles & Parts
# 8       9                         Ford Motor        Motor Vehicles & Parts
# 9      10                               AT&T            Telecommunications
# 10     11                   General Electric                   Industrials
# ...

# %%
#Summary  function

# %%
df.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df.head().T          ### For Transposing data
# Out:
#                                0                   1  \
# Rank                           1                   2
# Company                  Walmart         Exxon Mobil
# Sector                 Retailing              Energy
# Industry   General Merchandisers  Petroleum Refining
# Location         Bentonville, AR          Irving, TX
# Revenue                   482130              246204
# Profits                    14694               16150
# Employees                2300000               75600
#
#                                      2  \
# Rank                                 3
# Company                          Apple
# Sector                      Technology
# Industry   Computers, Office Equipment
# Location                 Cupertino, CA
# Revenue                         233715
# Profits                          53394
# Employees                       110000
#
#                                                   3                         4
# ...

# %%
df.head(10)
# Out:
#    Rank             Company                  Sector  \
# 0     1             Walmart               Retailing
# 1     2         Exxon Mobil                  Energy
# 2     3               Apple              Technology
# 3     4  Berkshire Hathaway              Financials
# 4     5            McKesson             Health Care
# 5     6  UnitedHealth Group             Health Care
# 6     7          CVS Health    Food and Drug Stores
# 7     8      General Motors  Motor Vehicles & Parts
# 8     9          Ford Motor  Motor Vehicles & Parts
# 9    10                AT&T      Telecommunications
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# ...

# %%
df.tail()
# Out:
#      Rank                     Company                        Sector  \
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                         Industry       Location  Revenue  Profits  Employees
# 995             Commercial Banks   Westbury, NY     1902      -47       3448
# 996  Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 997  Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 998                Food Services     Dublin, OH     1896      161      21200
# 999         Industrial Machinery  Wauwatosa, WI     1895       46       5480

# %%
df.tail(10)
# Out:
#      Rank                     Company                        Sector  \
# 990   991           BlueLinx Holdings                   Wholesalers
# 991   992                      Revlon            Household Products
# 992   993       DeVry Education Group             Business Services
# 993   994                MDC Holdings    Engineering & Construction
# 994   995                   EP Energy                        Energy
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                             Industry           Location  Revenue  Profits  \
# 990         Wholesalers: Diversified        Atlanta, GA     1917      -12
# ...

# %%
#for all columns
df.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# Rank         1000 non-null int64
# Company      1000 non-null object
# Sector       1000 non-null object
# Industry     1000 non-null object
# Location     1000 non-null object
# Revenue      1000 non-null int64
# Profits      1000 non-null int64
# Employees    1000 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#              Rank        Revenue       Profits     Employees
# count  1000.00000    1000.000000   1000.000000  1.000000e+03
# mean    500.49600   13535.525000    894.093000  3.302800e+04
# std     288.81727   28820.519135   3297.063594  9.042769e+04
# min       1.00000    1895.000000 -23119.000000  5.200000e+01
# 25%     250.75000    2898.250000     82.750000  6.405250e+03
# 50%     500.50000    5113.000000    282.500000  1.251950e+04
# 75%     750.25000   11386.000000    784.500000  2.812500e+04
# max    1000.00000  482130.000000  53394.000000  2.300000e+06

# %%
df.describe(include=['object'])
# Out:
#                       Company      Sector                    Industry  \
# count                    1000        1000                        1000
# unique                    996          21                          73
# top     Host Hotels & Resorts  Financials  Specialty Retailers: Other
# freq                        2         139                          42
#
#             Location
# count           1000
# unique           416
# top     New York, NY
# freq              72

# %%
df.nunique()
# Out:
# Rank         996
# Company      996
# Sector        21
# Industry      73
# Location     416
# Revenue      945
# Profits      760
# Employees    755
# dtype: int64

# %%
#selecting a single column from data set
df['Sector']
# Out:
# 0                         Retailing
# 1                            Energy
# 2                        Technology
# 3                        Financials
# 4                       Health Care
# 5                       Health Care
# 6              Food and Drug Stores
# 7            Motor Vehicles & Parts
# 8            Motor Vehicles & Parts
# 9                Telecommunications
# 10                      Industrials
# 11                      Health Care
# 12               Telecommunications
# 13                           Energy
# 14                        Retailing
# 15                       Financials
# 16             Food and Drug Stores
# 17                       Technology
# 18             Food and Drug Stores
# 19                       Technology
# 20                      Health Care
# 21                      Health Care
# 22                       Financials
# 23              Aerospace & Defense
# 24                       Technology
# 25                       Financials
# ...

# %%
##Selecting multipe columns from data set
df[['Sector','Industry']]
# Out:
#                            Sector                                    Industry
# 0                       Retailing                       General Merchandisers
# 1                          Energy                          Petroleum Refining
# 2                      Technology                 Computers, Office Equipment
# 3                      Financials    Insurance: Property and Casualty (Stock)
# 4                     Health Care                    Wholesalers: Health Care
# 5                     Health Care     Health Care: Insurance and Managed Care
# 6            Food and Drug Stores                        Food and Drug Stores
# 7          Motor Vehicles & Parts                    Motor Vehicles and Parts
# 8          Motor Vehicles & Parts                    Motor Vehicles and Parts
# 9              Telecommunications                          Telecommunications
# 10                    Industrials                        Industrial Machinery
# ...

# %%
df[['Sector','Industry','Company']]
# Out:
#                            Sector                                    Industry  \
# 0                       Retailing                       General Merchandisers
# 1                          Energy                          Petroleum Refining
# 2                      Technology                 Computers, Office Equipment
# 3                      Financials    Insurance: Property and Casualty (Stock)
# 4                     Health Care                    Wholesalers: Health Care
# 5                     Health Care     Health Care: Insurance and Managed Care
# 6            Food and Drug Stores                        Food and Drug Stores
# 7          Motor Vehicles & Parts                    Motor Vehicles and Parts
# 8          Motor Vehicles & Parts                    Motor Vehicles and Parts
# 9              Telecommunications                          Telecommunications
# 10                    Industrials                        Industrial Machinery
# ...

# %%
#indexing - loc ,iloc
#select row by their position using iloc position [row,column]-select first 5 row
#loc gets rows (or column) with particular lables from index
#iloc gets rows(or column) at particular position in the index(so it only takes integer)

# %%
df.iloc[:5]
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df.iloc[:5,]
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df.iloc[5:]
# Out:
#      Rank                            Company                        Sector  \
# 5       6                 UnitedHealth Group                   Health Care
# 6       7                         CVS Health          Food and Drug Stores
# 7       8                     General Motors        Motor Vehicles & Parts
# 8       9                         Ford Motor        Motor Vehicles & Parts
# 9      10                               AT&T            Telecommunications
# 10     11                   General Electric                   Industrials
# 11     12                  AmerisourceBergen                   Health Care
# 12     13                            Verizon            Telecommunications
# 13     14                            Chevron                        Energy
# 14     15                             Costco                     Retailing
# 15     16                         Fannie Mae                    Financials
# ...

# %%
df.iloc[0]
# Out:
# Rank                             1
# Company                    Walmart
# Sector                   Retailing
# Industry     General Merchandisers
# Location           Bentonville, AR
# Revenue                     482130
# Profits                      14694
# Employees                  2300000
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#    Rank             Company      Sector  \
# 0     1             Walmart   Retailing
# 1     2         Exxon Mobil      Energy
# 2     3               Apple  Technology
# 3     4  Berkshire Hathaway  Financials
#
#                                    Industry         Location  Revenue  \
# 0                     General Merchandisers  Bentonville, AR   482130
# 1                        Petroleum Refining       Irving, TX   246204
# 2               Computers, Office Equipment    Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)        Omaha, NE   210821
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000

# %%
df.iloc[4:0]
# Out:
# Empty DataFrame
# Columns: [Rank, Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
df.iloc[2:5]
# Out:
#    Rank             Company       Sector  \
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
#select columns by their position
df.iloc[1:30 , 1:4]
# Out:
#                      Company                  Sector  \
# 1                Exxon Mobil                  Energy
# 2                      Apple              Technology
# 3         Berkshire Hathaway              Financials
# 4                   McKesson             Health Care
# 5         UnitedHealth Group             Health Care
# 6                 CVS Health    Food and Drug Stores
# 7             General Motors  Motor Vehicles & Parts
# 8                 Ford Motor  Motor Vehicles & Parts
# 9                       AT&T      Telecommunications
# 10          General Electric             Industrials
# 11         AmerisourceBergen             Health Care
# 12                   Verizon      Telecommunications
# 13                   Chevron                  Energy
# 14                    Costco               Retailing
# 15                Fannie Mae              Financials
# 16                    Kroger    Food and Drug Stores
# 17                Amazon.com              Technology
# ...

# %%
df.iloc[0:4,0:4]
# Out:
#    Rank             Company      Sector  \
# 0     1             Walmart   Retailing
# 1     2         Exxon Mobil      Energy
# 2     3               Apple  Technology
# 3     4  Berkshire Hathaway  Financials
#
#                                    Industry
# 0                     General Merchandisers
# 1                        Petroleum Refining
# 2               Computers, Office Equipment
# 3  Insurance: Property and Casualty (Stock)

# %%
df.iloc[0:4,0:6:1]
# Out:
#    Rank             Company      Sector  \
# 0     1             Walmart   Retailing
# 1     2         Exxon Mobil      Energy
# 2     3               Apple  Technology
# 3     4  Berkshire Hathaway  Financials
#
#                                    Industry         Location  Revenue
# 0                     General Merchandisers  Bentonville, AR   482130
# 1                        Petroleum Refining       Irving, TX   246204
# 2               Computers, Office Equipment    Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)        Omaha, NE   210821

# %%
df.iloc[0:4,0:6:2]
# Out:
#    Rank      Sector         Location
# 0     1   Retailing  Bentonville, AR
# 1     2      Energy       Irving, TX
# 2     3  Technology    Cupertino, CA
# 3     4  Financials        Omaha, NE

# %%
df.iloc[0:10:2,0:8:2]
# Out:
#    Rank                  Sector           Location  Profits
# 0     1               Retailing    Bentonville, AR    14694
# 2     3              Technology      Cupertino, CA    53394
# 4     5             Health Care  San Francisco, CA     1476
# 6     7    Food and Drug Stores     Woonsocket, RI     5237
# 8     9  Motor Vehicles & Parts       Dearborn, MI     7373

# %%
df.iloc[0:100]['Location']
# Out:
# 0             Bentonville, AR
# 1                  Irving, TX
# 2               Cupertino, CA
# 3                   Omaha, NE
# 4           San Francisco, CA
# 5              Minnetonka, MN
# 6              Woonsocket, RI
# 7                 Detroit, MI
# 8                Dearborn, MI
# 9                  Dallas, TX
# 10              Fairfield, CT
# 11           Chesterbrook, PA
# 12               New York, NY
# 13              San Ramon, CA
# 14               Issaquah, WA
# 15             Washington, DC
# 16             Cincinnati, OH
# 17                Seattle, WA
# 18              Deerfield, IL
# 19              Palo Alto, CA
# 20                 Dublin, OH
# 21              St. Louis, MO
# 22               New York, NY
# 23                Chicago, IL
# 24                Redmond, WA
# 25              Charlotte, NC
# 26          San Francisco, CA
# 27                Atlanta, GA
# 28               New York, NY
# 29                Houston, TX
#                ...
# ...

# %%
df.iloc[0:10][['Sector','Location','Profits']]
# Out:
#                    Sector           Location  Profits
# 0               Retailing    Bentonville, AR    14694
# 1                  Energy         Irving, TX    16150
# 2              Technology      Cupertino, CA    53394
# 3              Financials          Omaha, NE    24083
# 4             Health Care  San Francisco, CA     1476
# 5             Health Care     Minnetonka, MN     5813
# 6    Food and Drug Stores     Woonsocket, RI     5237
# 7  Motor Vehicles & Parts        Detroit, MI     9687
# 8  Motor Vehicles & Parts       Dearborn, MI     7373
# 9      Telecommunications         Dallas, TX    13345

# %%
df.iloc[:10,:10]###first 10 rows and first 10 columns
# Out:
#    Rank             Company                  Sector  \
# 0     1             Walmart               Retailing
# 1     2         Exxon Mobil                  Energy
# 2     3               Apple              Technology
# 3     4  Berkshire Hathaway              Financials
# 4     5            McKesson             Health Care
# 5     6  UnitedHealth Group             Health Care
# 6     7          CVS Health    Food and Drug Stores
# 7     8      General Motors  Motor Vehicles & Parts
# 8     9          Ford Motor  Motor Vehicles & Parts
# 9    10                AT&T      Telecommunications
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# ...

# %%
df.iloc[300:,4:]
# Out:
#                     Location  Revenue  Profits  Employees
# 300                Miami, FL     9474      803       7749
# 301            Grapevine, TX     9364      403      40600
# 302          Los Angeles, CA     9351      312      13400
# 303               Austin, MN     9264      686      20700
# 304               Summit, NJ     9256     1602       6971
# 305             Richmond, VA     9249     -615       4100
# 306             San Jose, CA     9248     1228      16800
# 307              Norwalk, CT     9224     2551      15500
# 308            Las Vegas, NV     9190     -448      57950
# 309         Auburn Hills, MI     9170      457      59350
# 310         Jacksonville, FL     9132      527      54091
# 311              Phoenix, AZ     9115      750      33000
# 312              Corning, NY     9111     1339      35700
# 313                Omaha, NE     8992      251      22000
# 314        Downers Grove, IL     8982       17       9200
# ...

# %%
df.iloc[0][4]
# Out:
# 'Bentonville, AR'

# %%
df.iloc[0][['Sector','Industry']]
# Out:
# Sector                  Retailing
# Industry    General Merchandisers
# Name: 0, dtype: object

# %%
df.iloc[0]['Company']
# Out:
# 'Walmart'

# %%
## For loc function
df2=pd.read_csv('fortune1000.csv',index_col='Company')
df2
# Out:
#                                    Rank                        Sector  \
# Company
# Walmart                               1                     Retailing
# Exxon Mobil                           2                        Energy
# Apple                                 3                    Technology
# Berkshire Hathaway                    4                    Financials
# McKesson                              5                   Health Care
# UnitedHealth Group                    6                   Health Care
# CVS Health                            7          Food and Drug Stores
# General Motors                        8        Motor Vehicles & Parts
# Ford Motor                            9        Motor Vehicles & Parts
# AT&T                                 10            Telecommunications
# General Electric                     11                   Industrials
# AmerisourceBergen                    12                   Health Care
# ...

# %%
df2.loc['Walmart']
# Out:
# Rank                             1
# Sector                   Retailing
# Industry     General Merchandisers
# Location           Bentonville, AR
# Revenue                     482130
# Profits                      14694
# Employees                  2300000
# Name: Walmart, dtype: object

# %%
df2.loc['Walmart']
# Out:
# Rank                             1
# Sector                   Retailing
# Industry     General Merchandisers
# Location           Bentonville, AR
# Revenue                     482130
# Profits                      14694
# Employees                  2300000
# Name: Walmart, dtype: object

# %%
df2.loc['AT&T']
# Out:
# Rank                         10
# Sector       Telecommunications
# Industry     Telecommunications
# Location             Dallas, TX
# Revenue                  146801
# Profits                   13345
# Employees                281450
# Name: AT&T, dtype: object

# %%
df2.loc['Walmart'][3]
# Out:
# 'Bentonville, AR'

# %%
df2.loc['Walmart'][3:6]
# Out:
# Location    Bentonville, AR
# Revenue              482130
# Profits               14694
# Name: Walmart, dtype: object

# %%
df2.loc['Walmart']['Sector']
# Out:
# 'Retailing'

# %%
#null values

# %%
df.isnull()
# Out:
#       Rank  Company  Sector  Industry  Location  Revenue  Profits  Employees
# 0    False    False   False     False     False    False    False      False
# 1    False    False   False     False     False    False    False      False
# 2    False    False   False     False     False    False    False      False
# 3    False    False   False     False     False    False    False      False
# 4    False    False   False     False     False    False    False      False
# 5    False    False   False     False     False    False    False      False
# 6    False    False   False     False     False    False    False      False
# 7    False    False   False     False     False    False    False      False
# 8    False    False   False     False     False    False    False      False
# 9    False    False   False     False     False    False    False      False
# 10   False    False   False     False     False    False    False      False
# ...

# %%
df.isnull().sum()
# Out:
# Rank         0
# Company      0
# Sector       0
# Industry     0
# Location     0
# Revenue      0
# Profits      0
# Employees    0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Rank         0.0
# Company      0.0
# Sector       0.0
# Industry     0.0
# Location     0.0
# Revenue      0.0
# Profits      0.0
# Employees    0.0
# dtype: float64

# %%
##Series related functions

# %%
df['Profits'].sum()
# Out:
# 894093

# %%
df['Profits'].max()
# Out:
# 53394

# %%
df['Profits'].min()
# Out:
# -23119

# %%
df['Profits'].mean()
# Out:
# 894.093

# %%
df['Profits'].std()
# Out:
# 3297.063593971716

# %%
df['Profits'].var()
# Out:
# 10870628.342693688

# %%
df['Profits'].median()
# Out:
# 282.5

# %%
df['Profits'].mode()
# Out:
# 0    172
# dtype: int64

# %%
df['Sector'].mode()
# Out:
# 0    Financials
# dtype: object

# %%
df['Company'].mode()
# Out:
# 0        Host Hotels & Resorts
# 1                 Noble Energy
# 2    Portland General Electric
# 3            Regions Financial
# dtype: object

# %%
df['Company'].unique()
# Out:
# array(['Walmart', 'Exxon Mobil', 'Apple', 'Berkshire Hathaway',
#        'McKesson', 'UnitedHealth Group', 'CVS Health', 'General Motors',
#        'Ford Motor', 'AT&T', 'General Electric', 'AmerisourceBergen',
#        'Verizon', 'Chevron', 'Costco', 'Fannie Mae', 'Kroger',
#        'Amazon.com', 'Walgreens Boots Alliance', 'HP', 'Cardinal Health',
#        'Express Scripts Holding', 'J.P. Morgan Chase', 'Boeing',
#        'Microsoft', 'Bank of America Corp.', 'Wells Fargo', 'Home Depot',
#        'Citigroup', 'Phillips 66', 'IBM', 'Valero Energy', 'Anthem',
#        'Procter & Gamble', 'State Farm Insurance Cos.', 'Alphabet',
#        'Comcast', 'Target', 'Johnson & Johnson', 'MetLife',
#        'Archer Daniels Midland', 'Marathon Petroleum', 'Freddie Mac',
#        'PepsiCo', 'United Technologies', 'Aetna', 'Lowe’s', 'UPS', 'AIG',
#        'Prudential Financial', 'Intel', 'Humana', 'Disney',
#        'Cisco Systems', 'Pfizer', 'Dow Chemical', 'Sysco', 'FedEx',
# ...

# %%
df['Profits'].unique()
# Out:
# array([ 14694,  16150,  53394,  24083,   1476,   5813,   5237,   9687,
#          7373,  13345,  -6126,   -135,  17879,   4587,   2377,  10954,
#          2039,    596,   4220,   4554,   1215,   2476,  24442,   5176,
#         12193,  15888,  22894,   7009,  17242,   4227,  13190,   3990,
#          2560,   7036,   6229,  16348,   8163,   3363,  15409,   5310,
#          1849,   2852,   6376,   5452,   7608,   2390,   2546,   4844,
#          2196,   5642,  11420,   1276,   8382,   8981,   6960,   7685,
#           687,   1050,   2102,   3605,    257,   7351,   2129,    215,
#          1189,   1220,   7610,   4526,    581,   1563,    897,   4442,
#           514,   6083,   4768,   1425,   9938,   6127,   2094,   7340,
#          2171,   1214,     56,    781,   5163,  18108,   1965,   2965,
#          2278,  -4428,   3273,    187,   4833,   7267,   2269,   8306,
#          1940,   1540,   3833,    815,   1953,    572,   1072,   2521,
# ...

# %%
df['Company'].value_counts()
# Out:
# Host Hotels & Resorts                     2
# Regions Financial                         2
# Portland General Electric                 2
# Noble Energy                              2
# MDU Resources Group                       1
# Applied Industrial Technologies           1
# Meritage Homes                            1
# Citrix Systems                            1
# Puget Energy                              1
# HD Supply Holdings                        1
# BlackRock                                 1
# Post Holdings                             1
# C.R. Bard                                 1
# Franklin Resources                        1
# Erie Insurance Group                      1
# Core-Mark Holding                         1
# ScanSource                                1
# Whirlpool                                 1
# Vantiv                                    1
# Energy Future Holdings                    1
# Olin                                      1
# ...

# %%
df['Sector'].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Food, Beverages & Tobacco        43
# Materials                        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Apparel                          15
# Telecommunications               15
# Food and Drug Stores             15
# Name: Sector, dtype: int64

# %%
df['Revenue'].value_counts()
# Out:
# 2986     3
# 2084     3
# 2197     3
# 2692     2
# 2707     2
# 3779     2
# 5308     2
# 2307     2
# 2290     2
# 2780     2
# 2247     2
# 3159     2
# 3133     2
# 5176     2
# 1898     2
# 2264     2
# 2377     2
# 3593     2
# 2682     2
# 6070     2
# 2371     2
# 2530     2
# 5565     2
# 2506     2
# 3506     2
# 3540     2
# 3496     2
# 4515     2
# 2604     2
# 4664     2
#         ..
# 5291     1
# 3321     1
# 5373     1
# 3327     1
# 11554    1
# 3384     1
# 11574    1
# 7477     1
# 3378     1
# 8185     1
# 2972     1
# 11802    1
# 7467     1
# 3367     1
# 3653     1
# 27940    1
# 40222    1
# 9474     1
# 12712    1
# 9499     1
# 9496     1
# 27925    1
# 5392     1
# 3343     1
# 2330     1
# 40204    1
# 19110    1
# 44294    1
# 11524    1
# 6145     1
# Name: Revenue, Length: 945, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# New York, NY               72
# Houston, TX                44
# Atlanta, GA                23
# Chicago, IL                22
# Dallas, TX                 16
# St. Louis, MO              14
# Cleveland, OH              11
# San Francisco, CA          11
# Omaha, NE                  10
# Columbus, OH               10
# Pittsburgh, PA             10
# San Jose, CA               10
# Richmond, VA                9
# Stamford, CT                9
# Charlotte, NC               9
# Milwaukee, WI               9
# Minneapolis, MN             8
# Las Vegas, NV               8
# Los Angeles, CA             8
# Phoenix, AZ                 8
# Cincinnati, OH              8
# Boston, MA                  8
# McLean, VA                  8
# Denver, CO                  8
# Irving, TX                  8
# Memphis, TN                 7
# San Antonio, TX             7
# Tulsa, OK                   7
# Englewood, CO               7
# Irvine, CA                  7
#                            ..
# ...

# %%
df['Employees'].value_counts()
# Out:
# 13000     11
# 8000       9
# 14000      7
# 10000      7
# 12000      6
# 7300       6
# 5000       6
# 23000      6
# 25000      6
# 7000       5
# 15000      5
# 6700       5
# 12700      5
# 19000      5
# 4300       5
# 11000      4
# 20000      4
# 17000      4
# 6000       4
# 27000      4
# 9800       4
# 8100       4
# 8200       4
# 22000      4
# 6900       4
# 11400      4
# 12500      3
# 8400       3
# 7100       3
# 9200       3
#           ..
# 4700       1
# 7770       1
# 231000     1
# 341240     1
# 12886      1
# 6740       1
# 58963      1
# 12325      1
# 8818       1
# 2982       1
# 6800       1
# 56950      1
# 143600     1
# 3410       1
# 14726      1
# 3722       1
# 12864      1
# 19080      1
# 590        1
# 22150      1
# 24197      1
# 8550       1
# 7810       1
# 5761       1
# 54911      1
# 7841       1
# 88700      1
# 9850       1
# 161400     1
# 51200      1
# Name: Employees, Length: 755, dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
##Concatination operations

# %%
new_fortune={'Rank':'25', 'Company':'Dabur', 'Sector':'hjxgfy', 'Industry':'statistics', 'Location':'benglore', 'Revenue':'566424',
       'Profits':'4562', 'Employees':'454'}

# %%
new_fortune
# Out:
# {'Rank': '25',
#  'Company': 'Dabur',
#  'Sector': 'hjxgfy',
#  'Industry': 'statistics',
#  'Location': 'benglore',
#  'Revenue': '566424',
#  'Profits': '4562',
#  'Employees': '454'}

# %%
new_fortune_df=pd.DataFrame(new_fortune,index=[0])
new_fortune_df
# Out:
#   Rank Company  Sector    Industry  Location Revenue Profits Employees
# 0   25   Dabur  hjxgfy  statistics  benglore  566424    4562       454

# %%
df1=pd.concat([new_fortune_df,df],ignore_index=True)
df1.head()
# Out:
#   Rank             Company      Sector  \
# 0   25               Dabur      hjxgfy
# 1    1             Walmart   Retailing
# 2    2         Exxon Mobil      Energy
# 3    3               Apple  Technology
# 4    4  Berkshire Hathaway  Financials
#
#                                    Industry         Location Revenue Profits  \
# 0                                statistics         benglore  566424    4562
# 1                     General Merchandisers  Bentonville, AR  482130   14694
# 2                        Petroleum Refining       Irving, TX  246204   16150
# 3               Computers, Office Equipment    Cupertino, CA  233715   53394
# 4  Insurance: Property and Casualty (Stock)        Omaha, NE  210821   24083
#
#   Employees
# 0       454
# 1   2300000
# 2     75600
# 3    110000
# 4    331000

# %%
##Appending operations

# %%
df1=pd.DataFrame({'Company':['Dove','Machho'],'sr no':[1,2]})
df1
# Out:
#   Company  sr no
# 0    Dove      1
# 1  Machho      2

# %%
df2=pd.DataFrame({'Company':['IBM'],'id':[3]})
df2
# Out:
#   Company  id
# 0     IBM   3

# %%
df1.append(df2,ignore_index=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#   Company   id  sr no
# 0    Dove  NaN    1.0
# 1  Machho  NaN    2.0
# 2     IBM  3.0    NaN

# %%
df.append(new_fortune_df,ignore_index=True)
# Out:
#       Rank                            Company                        Sector  \
# 0        1                            Walmart                     Retailing
# 1        2                        Exxon Mobil                        Energy
# 2        3                              Apple                    Technology
# 3        4                 Berkshire Hathaway                    Financials
# 4        5                           McKesson                   Health Care
# 5        6                 UnitedHealth Group                   Health Care
# 6        7                         CVS Health          Food and Drug Stores
# 7        8                     General Motors        Motor Vehicles & Parts
# 8        9                         Ford Motor        Motor Vehicles & Parts
# 9       10                               AT&T            Telecommunications
# 10      11                   General Electric                   Industrials
# ...

# %%
##Filtering

# %%
df
# Out:
#      Rank                            Company                        Sector  \
# 0       1                            Walmart                     Retailing
# 1       2                        Exxon Mobil                        Energy
# 2       3                              Apple                    Technology
# 3       4                 Berkshire Hathaway                    Financials
# 4       5                           McKesson                   Health Care
# 5       6                 UnitedHealth Group                   Health Care
# 6       7                         CVS Health          Food and Drug Stores
# 7       8                     General Motors        Motor Vehicles & Parts
# 8       9                         Ford Motor        Motor Vehicles & Parts
# 9      10                               AT&T            Telecommunications
# 10     11                   General Electric                   Industrials
# ...

# %%
df[df['Profits']>50000]
# Out:
#    Rank Company      Sector                     Industry       Location  \
# 2     3   Apple  Technology  Computers, Office Equipment  Cupertino, CA
#
#    Revenue  Profits  Employees
# 2   233715    53394     110000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type('Profits')
# Out:
# str

# %%
df[df['Profits']>3000]['Company']
# Out:
# 0                            Walmart
# 1                        Exxon Mobil
# 2                              Apple
# 3                 Berkshire Hathaway
# 5                 UnitedHealth Group
# 6                         CVS Health
# 7                     General Motors
# 8                         Ford Motor
# 9                               AT&T
# 12                           Verizon
# 13                           Chevron
# 15                        Fannie Mae
# 18          Walgreens Boots Alliance
# 19                                HP
# 22                 J.P. Morgan Chase
# 23                            Boeing
# 24                         Microsoft
# 25             Bank of America Corp.
# 26                       Wells Fargo
# 27                        Home Depot
# 28                         Citigroup
# 29                       Phillips 66
# 30                               IBM
# 31                     Valero Energy
# 33                  Procter & Gamble
# ...

# %%
df[df['Profits']>6000][['Company','Employees']]
# Out:
#                          Company  Employees
# 0                        Walmart    2300000
# 1                    Exxon Mobil      75600
# 2                          Apple     110000
# 3             Berkshire Hathaway     331000
# 7                 General Motors     215000
# 8                     Ford Motor     199000
# 9                           AT&T     281450
# 12                       Verizon     177700
# 15                    Fannie Mae       7300
# 22             J.P. Morgan Chase     234598
# 24                     Microsoft     118000
# 25         Bank of America Corp.     213280
# 26                   Wells Fargo     264700
# 27                    Home Depot     385000
# 28                     Citigroup     231000
# 30                           IBM     411798
# 33              Procter & Gamble     110000
# 34     State Farm Insurance Cos.      70425
# 35                      Alphabet      61814
# 36                       Comcast     153000
# ...

# %%
df[(df['Profits']>30000)& (df['Employees']<1000000)]
# Out:
#    Rank Company      Sector                     Industry       Location  \
# 2     3   Apple  Technology  Computers, Office Equipment  Cupertino, CA
#
#    Revenue  Profits  Employees
# 2   233715    53394     110000

# %%
new_df=df[(df['Profits']>300000)& (df['Employees']<1000000)]
new_df
# Out:
# Empty DataFrame
# Columns: [Rank, Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
df[(df['Profits']>6000)& (df['Rank']<100)][['Company','Sector']]
# Out:
#                         Company                     Sector
# 0                       Walmart                  Retailing
# 1                   Exxon Mobil                     Energy
# 2                         Apple                 Technology
# 3            Berkshire Hathaway                 Financials
# 7                General Motors     Motor Vehicles & Parts
# 8                    Ford Motor     Motor Vehicles & Parts
# 9                          AT&T         Telecommunications
# 12                      Verizon         Telecommunications
# 15                   Fannie Mae                 Financials
# 22            J.P. Morgan Chase                 Financials
# 24                    Microsoft                 Technology
# 25        Bank of America Corp.                 Financials
# 26                  Wells Fargo                 Financials
# 27                   Home Depot                  Retailing
# 28                    Citigroup                 Financials
# ...

# %%
df.Company.value_counts()
# Out:
# Host Hotels & Resorts                     2
# Regions Financial                         2
# Portland General Electric                 2
# Noble Energy                              2
# MDU Resources Group                       1
# Applied Industrial Technologies           1
# Meritage Homes                            1
# Citrix Systems                            1
# Puget Energy                              1
# HD Supply Holdings                        1
# BlackRock                                 1
# Post Holdings                             1
# C.R. Bard                                 1
# Franklin Resources                        1
# Erie Insurance Group                      1
# Core-Mark Holding                         1
# ScanSource                                1
# Whirlpool                                 1
# Vantiv                                    1
# Energy Future Holdings                    1
# Olin                                      1
# ...
